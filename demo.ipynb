# %%
# This demo outputs 5 continuous prediction values between the range [0, 1] corresponding to each trait for a video.

# %%
# !sudo pip install scikit-video
# !sudo pip install chainer
# Out:
# Collecting scikit-video
#   Downloading https://files.pythonhosted.org/packages/b1/a6/c69cad508139a342810ae46e946ebb3256aa6e42f690d901bb68f50582e3/scikit_video-1.1.11-py2.py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 14.4MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from scikit-video) (1.19.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from scikit-video) (7.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from scikit-video) (1.4.1)
# Installing collected packages: scikit-video
# Successfully installed scikit-video-1.1.11
# Requirement already satisfied: chainer in /usr/local/lib/python3.6/dist-packages (7.4.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer) (1.15.0)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from chainer) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from chainer) (3.7.4.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer) (1.19.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from chainer) (3.0.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from chainer) (51.3.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/MyDrive/deep_impression-master/deep_impression-master
# Out:
# /content/drive/MyDrive/deep_impression-master/deep_impression-master

# %%
from util import load_model, predict_trait

# %%
model = load_model()

# %%
# data can be the path of any video that can be loaded by librosa and skvideo.
data = './_fJcW5234bY.001.mp4'
y = predict_trait(data, model)

print(data)
print('ValueExtraversion, ValueAgreeableness, ValueConscientiousness, ValueNeurotisicm, ValueOpenness')
print(y)
# Out:
# ./_fJcW5234bY.001.mp4
# ValueExtraversion, ValueAgreeableness, ValueConscientiousness, ValueNeurotisicm, ValueOpenness
# [0.44335812 0.51242155 0.36693776 0.4202078  0.47260243]
